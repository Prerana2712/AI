# %%
def bubbleSort(arr, size):
    for i in range(size - 1):
        for j in range(size - i - 1):
            if arr[j] > arr[j + 1]:
                swapped = True
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
         
        if not swapped:
            # if we haven't needed to make a single swap, we
            # can just exit the main loop.
            return
ch = 0
n = 0
arr = []
while ch != 4:
    ch = int(input("\nEnter the function to perform\n1)Create an array\n2)Insert the elements in array\n3)Perform Bubble sort and Display output\n4)exit\n(1,2,3,4):"))
    if ch == 1:
        n = int(input("Enter the number of elements to be present in array: "))
        if n == 0:
            print("List is empty")
            while n == 0:
                n = int(input("\nEnter the number of elements to be present in array: "))
                if n != 0:
                    break
    elif ch == 2:
        print("\nEnter values of array:")
        arr = [int(input()) for i in range(n)]
        if n==1:
            print("\nSorted array is:")
            print(arr)
    elif ch == 3:
        bubbleSort(arr, n)
        print("\nSorted array is:")
        print(arr)
    elif ch == 4:
        print("Exit")
    else:
        print("Wrong Choice")
# Out:
# Enter the function to perform
# 1)Create an array
# 2)Insert the elements in array
# 3)Perform Bubble sort and Display output
# 4)exit
# (1,2,3,4):1
# Enter the number of elements to be present in array: 0
# List is empty
#
# Enter the number of elements to be present in array: 0
#
# Enter the number of elements to be present in array: 5
#
# Enter the function to perform
# 1)Create an array
# 2)Insert the elements in array
# 3)Perform Bubble sort and Display output
# 4)exit
# (1,2,3,4):2
#
# Enter values of array:
# 7
# 2
# 5
# 1
# 9
#
# Enter the function to perform
# 1)Create an array
# 2)Insert the elements in array
# 3)Perform Bubble sort and Display output
# 4)exit
# (1,2,3,4):3
#
# Sorted array is:
# [1, 2, 5, 7, 9]
#
# Enter the function to perform
# 1)Create an array
# 2)Insert the elements in array
# 3)Perform Bubble sort and Display output
# 4)exit
# (1,2,3,4):1
# Enter the number of elements to be present in array: 1
#
# Enter the function to perform
# 1)Create an array
# 2)Insert the elements in array
# 3)Perform Bubble sort and Display output
# 4)exit
# (1,2,3,4):2
#
# Enter values of array:
# 5
#
# Sorted array is:
# [5]
#
# Enter the function to perform
# 1)Create an array
# 2)Insert the elements in array
# 3)Perform Bubble sort and Display output
# 4)exit
# (1,2,3,4):4
# Exit

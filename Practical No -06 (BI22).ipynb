# %%
import matplotlib.pyplot as plt
from skimage.io import imread, imshow
from skimage.color import rgb2gray
from skimage.filters import threshold_otsu, gaussian

# %%
def show_images(images, titles):
    for i, (image, title) in enumerate(zip(images, titles), 1):
        plt.subplot(1, len(images), i)
        plt.imshow(image, cmap='gray' if len(image.shape) == 2 else None)
        plt.title(title)
        plt.axis('off')
    plt.show()

# %%
# Load the image
image = imread(r"IMG_20190523_182625-EFFECTS.jpg")

# Display the original image
imshow(image)

# %%
# Extract red and yellow intensities
red, yellow = image.copy(), image.copy()
red[:, :, (1, 2)] = 0
yellow[:, :, 2] = 0
show_images(images=[red, yellow], titles=['Red Intensity', 'Yellow Intensity'])

# %%
# Convert the image to grayscale
gray_image = rgb2gray(image)
show_images(images=[image, gray_image], titles=["Color", "Grayscale"])

# %%
print("Colored image shape:", image.shape)
print("Grayscale image shape:", gray_image.shape)

# Perform Otsu thresholding
thresh = threshold_otsu(gray_image)
binary_image = gray_image > thresh
show_images(images=[gray_image, binary_image, binary_image], titles=["Grayscale", "Otsu Binary"])

# Apply Gaussian blur with a sigma of 20
blurred_image = gaussian(gray_image, sigma=20)
show_images(images=[gray_image, blurred_image], titles=["Gray Image", "20 Sigma Blur"])
# Out:
# Colored image shape: (2000, 4000, 3)
# Grayscale image shape: (2000, 4000)

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('IMG_20190523_182625-EFFECTS.jpg',0)

# %%
imshow(img)

# %%
# Calculate the frequency of pixels in the range 0-255
histogram = cv2.calcHist([img], [0], None, [256], [0, 256])

# %%
# Show the plotting graph of the histogram
plt.plot(histogram)
plt.title('Histogram')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.show()
